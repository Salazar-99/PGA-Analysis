# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_path = '/home/gerardo/Desktop/Projects/PGA-Analysis/data/driving-data/driving-data.csv'
raw_data = pd.read_csv(data_path)

# %%
raw_data.head()
# Out:
#                                   tournament        date  \
# 0                    Bob Hope Desert Classic  1980-01-13
# 1                               Phoenix Open  1980-01-20
# 2  Andy Williams-San Diego Open Invitational  1980-01-27
# 3                Bing Crosby National Pro-Am  1980-02-03
# 4                              Hawaiian Open  1980-02-10
#
#    average_driving_distance
# 0                245.353623
# 1                255.455128
# 2                253.961644
# 3                256.049275
# 4                258.930000

# %%
data = raw_data['average_driving_distance'].to_numpy()

# %%
data
# Out:
# array([245.35362319, 255.45512821, 253.96164384, ..., 289.24166667,
#        300.89855072, 302.26      ])

# %%
len(data)
# Out:
# 1720

# %%
indices = np.arange(1, len(data)+1)

# %%
plt.figure(figsize=(12,6))
plt.scatter(indices, data)
plt.grid(alpha=0.5)
plt.xlabel('Tournament Index')
plt.ylabel('Average Driving Distance')
# Out:
# Text(0, 0.5, 'Average Driving Distance')

# %%
plt.hist(data, bins=50)
# Out:
# (array([ 5.,  4.,  7., 12., 12., 24., 25., 24., 43., 53., 55., 59., 55.,
#         53., 64., 55., 53., 48., 51., 48., 54., 42., 54., 48., 53., 46.,
#         59., 45., 44., 57., 57., 48., 56., 59., 59., 39., 27., 30., 25.,
#         11., 10., 18.,  6.,  7.,  7.,  5.,  1.,  1.,  1.,  1.]),
#  array([239.2875    , 240.91789085, 242.54828169, 244.17867254,
#         245.80906338, 247.43945423, 249.06984507, 250.70023592,
#         252.33062676, 253.96101761, 255.59140845, 257.2217993 ,
#         258.85219014, 260.48258099, 262.11297183, 263.74336268,
#         265.37375352, 267.00414437, 268.63453521, 270.26492606,
#         271.8953169 , 273.52570775, 275.15609859, 276.78648944,
#         278.41688028, 280.04727113, 281.67766197, 283.30805282,
#         284.93844366, 286.56883451, 288.19922535, 289.8296162 ,
#         291.46000704, 293.09039789, 294.72078873, 296.35117958,
#         297.98157042, 299.61196127, 301.24235211, 302.87274296,
#         304.5031338 , 306.13352465, 307.76391549, 309.39430634,
#         311.02469718, 312.65508803, 314.28547887, 315.91586972,
#         317.54626056, 319.17665141, 320.80704225]),
#  <BarContainer object of 50 artists>)
