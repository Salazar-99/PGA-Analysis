# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_path = '/home/gerardo/Desktop/Projects/PGA-Analysis/data/driving-data/driving-data.csv'
raw_data = pd.read_csv(data_path)

# %%
raw_data.head()
# Out:
#                                   tournament        date  \
# 0                    Bob Hope Desert Classic  1980-01-13
# 1                               Phoenix Open  1980-01-20
# 2  Andy Williams-San Diego Open Invitational  1980-01-27
# 3                Bing Crosby National Pro-Am  1980-02-03
# 4                              Hawaiian Open  1980-02-10
#
#    average_driving_distance
# 0                245.353623
# 1                255.455128
# 2                253.961644
# 3                256.049275
# 4                258.930000

# %%
data = raw_data['average_driving_distance'].to_numpy()

# %%
data
# Out:
# array([245.35362319, 255.45512821, 253.96164384, ..., 289.24166667,
#        300.89855072, 302.26      ])

# %%
len(data)
# Out:
# 1720

# %%
indices = np.arange(1, len(data)+1)

# %%
plt.figure(figsize=(12,6))
plt.scatter(indices, data)
plt.grid(alpha=0.5)
plt.xlabel('Tournament Index $t$', fontsize=14)
plt.ylabel('Average Driving Distance', fontsize=14)
plt.savefig('/home/gerardo/Desktop/Projects/PGA-Analysis/reports/figures/average-driving-distance-raw.png')

# %%
plt.hist(data, bins=35, alpha=0.6)
plt.grid(alpha=0.5)
